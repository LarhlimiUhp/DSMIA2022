# %%
#step 1- Mount your Google Drive to Collaboratory

from google.colab import drive 
drive.mount('/content/gdrive')

#step 2- Now you will see your Google Drive files in the left pane (file explorer). Right click on the file that you need to import and select çopy path. Then import as usual in pandas, using this copied path.

import pandas as pd 
df=pd.read_csv('gdrive/My Drive/IA/Fifa_world_cup_matches.csv',index_col=0, parse_dates=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df2=pd.read_csv('gdrive/My Drive/IA/Salary.csv',index_col=0, parse_dates=True)

# %%
df2[:]

# %%
df.head(20)

# %%
type(df["possession team2"][:])
# Out:
# pandas.core.series.Series

# %%
df.info()

# %%
df

# %%
df["date"]=pd.to_datetime(df["date"]) # changer de type de donnes

# %%
df["possession team1"]
# Out:
# team1
# QATAR            42%
# ENGLAND          72%
# SENEGAL          44%
# UNITED STATES    51%
# ARGENTINA        64%
#                 ...
# ENGLAND          54%
# ARGENTINA        34%
# FRANCE           34%
# CROATIA          45%
# ARGENTINA        46%
# Name: possession team1, Length: 64, dtype: object

# %%
l =[3,5,6]
#print(len(l))
for x in l:
  print(x)
# Out:
# 3
# 5
# 6

# %%
df
# Out:
#                       team2 possession team1 possession team2  \
# team1
# QATAR               ECUADOR              42%              50%
# ENGLAND                IRAN              72%              19%
# SENEGAL         NETHERLANDS              44%              45%
# UNITED STATES         WALES              51%              39%
# ARGENTINA      SAUDI ARABIA              64%              24%
# ...                     ...              ...              ...
# ENGLAND              FRANCE              54%              36%
# ARGENTINA           CROATIA              34%              54%
# FRANCE              MOROCCO              34%              55%
# CROATIA             MOROCCO              45%              45%
# ARGENTINA            FRANCE              46%              40%
#
#               possession in contest  number of goals team1  \
# team1
# QATAR                            8%                      0
# ENGLAND                          9%                      6
# ...

# %%
x=df["possession team2"][:]
y =[float(x[i].strip('%'))/100 for i in range(len(x))]
df["possession team2"]=y

# %%
df
# Out:
#                       team2 possession team1  possession team2  \
# team1
# QATAR               ECUADOR              42%              0.50
# ENGLAND                IRAN              72%              0.19
# SENEGAL         NETHERLANDS              44%              0.45
# UNITED STATES         WALES              51%              0.39
# ARGENTINA      SAUDI ARABIA              64%              0.24
# ...                     ...              ...               ...
# ENGLAND              FRANCE              54%              0.36
# ARGENTINA           CROATIA              34%              0.54
# FRANCE              MOROCCO              34%              0.55
# CROATIA             MOROCCO              45%              0.45
# ARGENTINA            FRANCE              46%              0.40
#
#               possession in contest  number of goals team1  \
# team1
# QATAR                            8%                      0
# ENGLAND                          9%                      6
# ...

# %% [markdown]
# Régression linéaire avec scikit learn
#
# Maintenant que l’on a compris le fonctionnement de la régression linéaire, voyons comment implémenter ça avec Python.
#
# Scikit learn est la caverne d’Alibaba du data scientist. Quasiment tout y est ! Voici comment implémenter un modèle de régression linéaire avec scikit learn.

# %%
data=pd.read_csv('gdrive/My Drive/IA/Salary.csv',index_col=0, parse_dates=True) #pd.read_csv('gdrive/My Drive/IA2023/Salary.csv')

# %%
from sklearn.linear_model import LinearRegression 
# le module scikit

# %%
d=data.to_numpy()

# %%
print(d.shape)
# Out:
# (35, 1)

# %%
import numpy as np
# On transforme les colonnes en array
x = np.array(data["YearsExperience"])
y = np.array(data['Salary'])

# On doit transformer la forme des vecteurs pour qu'ils puissent être
# utilisés par Scikit learn

x = x.reshape(-1,1)
y = y.reshape(-1,1)
